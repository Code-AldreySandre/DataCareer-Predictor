# %% [markdown]
# ## Preprocessamento

# %%
import sys
import os 

sys.path.append(os.path.abspath(os.path.join('..')))

from src.preprocess import clean_data, transform_experience, process_multilabel_features, encode_and_format, save_processed_data
from src.data_loader import load_raw_data, get_labeled_data

df = load_raw_data()
df = get_labeled_data(df)
df = clean_data(df)
df = transform_experience(df)
df = process_multilabel_features(df)
df_final = encode_and_format(df)

save_processed_data(df_final)
# Out:
# Sucesso: Dataset carregado com 4271 instâncias e 13 atributos.
# Seleção KDD: 1290 instâncias removidas por falta de rótulo.
# Total para modelagem: 2981 instâncias.
# Dados salvos com sucesso em: /home/aldrey-sandre/Documents/GitHub/DataCareer-Predictor/src/../data/processed/dataset_final.pkl
